# %% [markdown]
# ### Append path because this file is not in the main directory

# %%
import sys
sys.path.append("../src/")
sys.path.append("../")

# %% [markdown]
# ### Import stuff

# %%
import nudobe

# %% [markdown]
# ### Get Limits

# %% [markdown]
# We can get limits on the different Wilson coefficients and the related scales via:

# %%
#Limits for operator groups
nudobe.functions.get_limits_LEFT(2.3e+26, "136Xe", method = "QRPA", groups = True)
# Out:
#                  Limits  Scales [GeV]
# m_bb       2.374252e-11  2.548845e+15
# VL(6)      7.383143e-10  9.053457e+06
# VR(6)      9.649115e-08  7.919383e+05
# T(6)       4.027559e-10  1.225785e+07
# S(6)       1.460841e-10  2.035325e+07
# V(7)       7.487205e-06  1.257463e+04
# S1(9)      5.321385e-06  2.790809e+03
# S2(9)      4.913422e-08  7.122924e+03
# S3(9)      1.762655e-07  5.516983e+03
# S4(9)      3.027232e-08  7.847403e+03
# S5(9)      8.913241e-09  1.002139e+04
# V(9)       2.448529e-05  2.056620e+03
# Vtilde(9)  4.664940e-05  1.807865e+03

# %%
#Individual limits
nudobe.functions.get_limits_LEFT(2.3e+26, "136Xe", method = "QRPA")
# Out:
#                   Limits  Scales [GeV]
# m_bb        2.374252e-11  2.548845e+15
# SL(6)       1.460841e-10  2.035325e+07
# SR(6)       1.460841e-10  2.035325e+07
# T(6)        4.027559e-10  1.225785e+07
# VL(6)       7.383143e-10  9.053457e+06
# VR(6)       9.649115e-08  7.919383e+05
# VL(7)       7.487205e-06  1.257463e+04
# VR(7)       7.487205e-06  1.257463e+04
# 1L(9)       5.321385e-06  2.790809e+03
# 1R(9)       5.321385e-06  2.790809e+03
# 1L(9)prime  5.321385e-06  2.790809e+03
# 1R(9)prime  5.321385e-06  2.790809e+03
# 2L(9)       4.913422e-08  7.122924e+03
# 2R(9)       4.913422e-08  7.122924e+03
# 2L(9)prime  4.913422e-08  7.122924e+03
# 2R(9)prime  4.913422e-08  7.122924e+03
# 3L(9)       1.762655e-07  5.516983e+03
# 3R(9)       1.762655e-07  5.516983e+03
# 3L(9)prime  1.762655e-07  5.516983e+03
# 3R(9)prime  1.762655e-07  5.516983e+03
# 4L(9)       3.027232e-08  7.847403e+03
# 4R(9)       3.027232e-08  7.847403e+03
# 5L(9)       8.913241e-09  1.002139e+04
# 5R(9)       8.913241e-09  1.002139e+04
# 6(9)        2.448529e-05  2.056620e+03
# 6(9)prime   2.448529e-05  2.056620e+03
# 7(9)        4.664940e-05  1.807865e+03
# 7(9)prime   4.664940e-05  1.807865e+03
# 8(9)        2.448529e-05  2.056620e+03
# 8(9)prime   2.448529e-05  2.056620e+03
# 9(9)        4.664940e-05  1.807865e+03
# 9(9)prime   4.664940e-05  1.807865e+03

# %%
#Changing the PSF_scheme
nudobe.functions.get_limits_LEFT(2.3e+26, "136Xe", method = "QRPA", PSF_scheme = "B")
# Out:
#                   Limits  Scales [GeV]
# m_bb        2.588350e-11  2.338015e+15
# SL(6)       1.592572e-10  1.949331e+07
# SR(6)       1.592572e-10  1.949331e+07
# T(6)        4.390744e-10  1.173994e+07
# VL(6)       8.116363e-10  8.634842e+06
# VR(6)       1.044624e-07  7.611234e+05
# VL(7)       8.162363e-06  1.221790e+04
# VR(7)       8.162363e-06  1.221790e+04
# 1L(9)       5.801241e-06  2.743032e+03
# 1R(9)       5.801241e-06  2.743032e+03
# 1L(9)prime  5.801241e-06  2.743032e+03
# 1R(9)prime  5.801241e-06  2.743032e+03
# 2L(9)       5.356489e-08  7.000984e+03
# 2R(9)       5.356489e-08  7.000984e+03
# 2L(9)prime  5.356489e-08  7.000984e+03
# 2R(9)prime  5.356489e-08  7.000984e+03
# 3L(9)       1.921602e-07  5.422536e+03
# 3R(9)       1.921602e-07  5.422536e+03
# 3L(9)prime  1.921602e-07  5.422536e+03
# 3R(9)prime  1.921602e-07  5.422536e+03
# 4L(9)       3.300213e-08  7.713060e+03
# 4R(9)       3.300213e-08  7.713060e+03
# 5L(9)       9.716992e-09  9.849830e+03
# 5R(9)       9.716992e-09  9.849830e+03
# 6(9)        2.691694e-05  2.018041e+03
# 6(9)prime   2.691694e-05  2.018041e+03
# 7(9)        5.128217e-05  1.773952e+03
# 7(9)prime   5.128217e-05  1.773952e+03
# 8(9)        2.691694e-05  2.018041e+03
# 8(9)prime   2.691694e-05  2.018041e+03
# 9(9)        5.128217e-05  1.773952e+03
# 9(9)prime   5.128217e-05  1.773952e+03

# %%
#using a different operator basis
#note that some WCs that have been used in the literature previously
#do not contribute to 0nuBB. Yet, we still kept them to make this explicit
#The fact that we kept WCs that do not contribute results in warnings here
nudobe.functions.get_limits_LEFT(2.3e+26, "136Xe", basis = "e")
# Out:
# /Users/scholer/Downloads/nudobe-main/ExampleNotebooks/../src/EFT.py:664: RuntimeWarning: divide by zero encountered in double_scalars
#   return(1/inverse_result)
#               Limits  Scales [GeV]
# m_bb    3.023437e-11  2.001563e+15
# V+AV+A  5.624690e-08  7.334505e+05
# V+AV-A  7.780453e-10  6.236166e+06
# TRTR    4.244463e-10  8.443232e+06
# S+PS+P  1.827596e-10  1.286708e+07
# S+PS-P  1.827596e-10  1.286708e+07
# VL(7)   1.873385e-05  9.262454e+03
# VR(7)   1.873385e-05  9.262454e+03
# 1LLL    1.677024e-10  9.592876e+03
# 1LLR    1.677024e-10  9.592876e+03
# 1RRL    1.677024e-10  9.592876e+03
# 1RRR    1.677024e-10  9.592876e+03
# 1RLL    6.084442e-11  1.174931e+04
# 1RLR    6.084442e-11  1.174931e+04
# 2LLL    9.474760e-11  2.164788e+04
# 2LLR    9.474760e-11  2.164788e+04
# 2RRL    9.474760e-11  2.164788e+04
# 2RRR    9.474760e-11  2.164788e+04
# 3LLL    4.985584e-08  3.071238e+03
# 3LLR    4.985584e-08  3.071238e+03
# 3RRL    4.985584e-08  3.071238e+03
# 3RRR    4.985584e-08  3.071238e+03
# 3RLL    1.033239e-10  1.056858e+04
# 3RLR    1.033239e-10  1.056858e+04
# 4LLR    4.652812e-09  9.935415e+03
# 4LRR    4.652812e-09  9.935415e+03
# 4RRR    4.652812e-09  9.935415e+03
# 4RLR    4.652812e-09  9.935415e+03
# 5LLR    1.019685e-08  8.492507e+03
# 5LRR    1.019685e-08  8.492507e+03
# 5RRR    1.019685e-08  8.492507e+03
# 5RLR    1.019685e-08  8.492507e+03
# 1LRL    6.084442e-11  1.174931e+04
# 1LRR    6.084442e-11  1.174931e+04
# 3LRL    1.033239e-10  1.056858e+04
# 3LRR    1.033239e-10  1.056858e+04
# 4LLL    4.652812e-09  9.935415e+03
# 4LRL    4.652812e-09  9.935415e+03
# 4RRL    4.652812e-09  9.935415e+03
# 4RLL    4.652812e-09  9.935415e+03
# TLTL             inf  0.000000e+00
# 5LLL    1.019685e-08  8.492507e+03
# 5LRL    1.019685e-08  8.492507e+03
# 5RRL    1.019685e-08  8.492507e+03
# 5RLL    1.019685e-08  8.492507e+03
# 2LRL             inf  0.000000e+00
# 2LRR             inf  0.000000e+00
# 2RLL             inf  0.000000e+00
# 2RLR             inf  0.000000e+00
# TRTL             inf  0.000000e+00
# TLTR             inf  0.000000e+00
# V-AV+A           inf  0.000000e+00
# V-AV-A           inf  0.000000e+00
# S-PS+P           inf  0.000000e+00
# S-PS-P           inf  0.000000e+00

# %%
#Get SMEFT limits
nudobe.functions.get_limits_SMEFT(2.3e+26, "136Xe")
# Out:
#              Limits [GeV$^{4-d}$]  Scales [GeV]
# LH(5)                4.996095e-16  2.001563e+15
# LH(7)                1.651165e-20  3.927081e+06
# LHD1(7)              3.365183e-12  6.673143e+03
# LHD2(7)              6.107801e-12  5.470643e+03
# LHDe(7)              1.517434e-16  1.874836e+05
# LHW(7)               8.153378e-13  1.070420e+04
# LLduD1(7)            1.881755e-15  8.099887e+04
# LLQdH1(7)            7.782385e-17  2.342228e+05
# LLQdH2(7)            3.225689e-16  1.458117e+05
# LLQuH(7)             3.472322e-17  3.065209e+05
# LeudH(7)             1.068657e-14  4.539980e+04
# ddueue(9)            1.171069e-16  1.535619e+03
# dQdueL1(9)           5.987874e-18  2.783207e+03
# dQdueL2(9)           4.329341e-18  2.969721e+03
# QudueL1(9)           5.987874e-18  2.783207e+03
# QudueL2(9)           4.329341e-18  2.969721e+03
# dQQuLL1(9)           3.572954e-20  7.751657e+03
# dQQuLL2(9)           1.213494e-19  6.070053e+03
# QuQuLL1(9)           9.847949e-20  6.328938e+03
# QuQuLL2(9)           3.532881e-19  4.902010e+03
# dQdQLL1(9)           9.847949e-20  6.328938e+03
# dQdQLL2(9)           3.532881e-19  4.902010e+03
# LLH4W1(9)            2.694619e-17  2.060158e+03
# deueH2D(9)           1.245669e-19  6.038366e+03
# dLuLH2D2(9)          1.245669e-19  6.038366e+03
# duLLH2D(9)           6.217067e-20  6.938776e+03
# dQLeH2D2(9)          6.146642e-18  2.768678e+03
# dLQeH2D1(9)          2.579272e-18  3.293825e+03
# deQLH2D(9)           3.237538e-18  3.147437e+03
# QueLH2D2(9)          6.146642e-18  2.768678e+03
# QeuLH2D2(9)          4.444133e-18  2.954218e+03
# QLQLH2D2(9)          6.010601e-17  1.754755e+03
# QLQLH2D5(9)          6.010601e-17  1.754755e+03
# QQLLH2D2(9)          2.412809e-16  1.328910e+03
# eeH4D2(9)            3.084986e-17  2.005162e+03
# LLH4D23(9)           1.121451e-17  2.454957e+03
# LLH4D24(9)           2.476784e-16  1.321972e+03

# %% [markdown]
# ### Limit Plots

# %%
fig = nudobe.functions.get_limits_LEFT(2.3e+26, "136Xe", groups = True)["Limits"].plot.bar()
fig.set_yscale("log")
fig.grid(linestyle="--")

# %%
nudobe.plots.limits_LEFT(experiments = {"KamLAND" : {"half-life":2.3e+26,
                                                     "isotope" : "136Xe",
                                                     "label":"KamLAND-Zen"
                                                    },
                                        "GERDA" : {"half-life" : 1.8e+26,
                                                   "isotope" : "76Ge",
                                                   "label" : "GERDA"
                                                  }
                                       },
                         savefig = True,
                         file = "LEFT_limits.png"
                        )

# %%
nudobe.plots.limits_SMEFT(experiments = {"KamLAND" : {"half-life":2.3e+26,
                                                     "isotope" : "136Xe",
                                                     "label":"KamLAND-Zen"
                                                    },
                                        "GERDA" : {"half-life" : 1.8e+26,
                                                   "isotope" : "76Ge",
                                                   "label" : "GERDA"
                                                  }
                                       },
                         savefig = True,
                         file = "SMEFT_limits.png"
                        )

# %% [markdown]
# # Contour Limits

# %%
#Get contour limits for 2 WCs
contours = nudobe.functions.get_contours("m_bb", "VR(6)", 2.3e+26, "136Xe", phase = 0, PSF_scheme = "B")
contours
# Out:
#               m_bb     VR(6) min     VR(6) max
# 0    -3.359702e-11  2.059081e-08  2.781579e-08
# 1    -3.357724e-11  1.868168e-08  2.969642e-08
# 2    -3.355746e-11  1.727538e-08  3.107422e-08
# 3    -3.353768e-11  1.610682e-08  3.221429e-08
# 4    -3.351790e-11  1.508467e-08  3.320793e-08
# ...            ...           ...           ...
# 3393  3.351790e-11 -3.320793e-08 -1.508467e-08
# 3394  3.353768e-11 -3.221429e-08 -1.610682e-08
# 3395  3.355746e-11 -3.107422e-08 -1.727538e-08
# 3396  3.357724e-11 -2.969642e-08 -1.868168e-08
# 3397  3.359702e-11 -2.781579e-08 -2.059081e-08
#
# [3398 rows x 3 columns]

# %%
#Plot contour limits from one experiment
nudobe.plots.contours("m_bb", "VR(6)", phase = 0,
                      limits = {"KamLAND-Zen" : {"half-life" : 2.3e+26,
                                                 "isotope" : "136Xe",
                                                 "color" : "b",
                                                 "label" :"KamLAND-Zen"}
                             },
                      PSF_scheme = "B"
                     )

# %%
#Plot the limits obtained from different experiments together
nudobe.plots.contours("m_bb", "VR(6)",
                      phase = 0,
                      limits = {"KamLAND-Zen" : {"half-life" : 2.3e+26,
                                                 "isotope" : "136Xe",
                                                 "color" : "b",
                                                 "label" :"KamLAND-Zen"},
                                "GERDA" : {"half-life" : 1.8e+26,
                                           "isotope" : "76Ge",
                                           "color" : "r",
                                           "label" : "GERDA"},
                                "Cupid-Mo" : {"half-life" : 1.5e+24,
                                              "isotope" : "100Mo",
                                              "color" : "g",
                                              "label" : "Cupid-Mo"}
                               },
                      PSF_scheme = "B"
                     )

# %% [markdown]
# # Get Limits from a Model Class

# %% [markdown]
# Getting limits from a model class can be more useful than getting it from the functions module if you want to change PSFs, LECs or NMEs manually.

# %%
import numpy as np

# %%
#Initiate models
LEFT_model = nudobe.EFT.LEFT({}, method = "SM", unknown_LECs = True)
SMEFT_model = nudobe.EFT.SMEFT({}, method = "SM", unknown_LECs = True)

# %%
#Generate limits
LEFT_lims  = LEFT_model.get_limits(2.3e+26, "136Xe", groups = True)
SMEFT_lims = SMEFT_model.get_limits(2.3e+26, "136Xe")

# %%
LEFT_lims
# Out:
#                  Limits  Scales [GeV]
# m_bb       2.864685e-11  2.112483e+15
# VL(6)      9.193729e-10  8.113145e+06
# VR(6)      4.340446e-08  1.180777e+06
# T(6)       5.583745e-10  1.041052e+07
# S(6)       2.434734e-10  1.576556e+07
# V(7)       1.247867e-05  1.060585e+04
# S1(9)      2.665478e-06  3.204646e+03
# S2(9)      4.460633e-09  1.150948e+04
# S3(9)      2.508390e-08  8.148095e+03
# S4(9)      4.894022e-09  1.129801e+04
# S5(9)      2.681047e-09  1.274307e+04
# V(9)       3.076756e-06  3.113985e+03
# Vtilde(9)  5.861838e-06  2.737337e+03

# %%
SMEFT_lims
# Out:
#              Limits [GeV$^{4-d}$]  Scales [GeV]
# LH(5)                4.733765e-16  2.112483e+15
# LH(7)                1.564467e-20  3.998323e+06
# LHD1(7)              1.059501e-13  2.113325e+04
# LHD2(7)              4.068424e-12  6.264089e+03
# LHDe(7)              8.965338e-17  2.234315e+05
# LHW(7)               2.644475e-14  3.356501e+04
# LLduD1(7)            1.686974e-16  1.809800e+05
# LLQdH1(7)            5.191805e-17  2.680570e+05
# LLQdH2(7)            2.121755e-16  1.676621e+05
# LLQuH(7)             2.312923e-17  3.509777e+05
# LeudH(7)             4.123291e-15  6.236180e+04
# ddueue(9)            1.183476e-17  2.428668e+03
# dQdueL1(9)           6.830421e-18  2.710881e+03
# dQdueL2(9)           4.938518e-18  2.892549e+03
# QudueL1(9)           6.830421e-18  2.710881e+03
# QudueL2(9)           4.938518e-18  2.892549e+03
# dQQuLL1(9)           5.951944e-21  1.109349e+04
# dQQuLL2(9)           1.086477e-20  9.835488e+03
# QuQuLL1(9)           4.951319e-21  1.150948e+04
# QuQuLL2(9)           2.784323e-20  8.148095e+03
# dQdQLL1(9)           4.951319e-21  1.150948e+04
# dQdQLL2(9)           2.784323e-20  8.148095e+03
# LLH4W1(9)            8.739756e-19  4.089782e+03
# deueH2D(9)           1.115284e-20  9.784145e+03
# dLuLH2D2(9)          1.115284e-20  9.784145e+03
# duLLH2D(9)           5.575062e-21  1.123958e+04
# dQLeH2D2(9)          7.011529e-18  2.696730e+03
# dLQeH2D1(9)          2.942199e-18  3.208231e+03
# deQLH2D(9)           3.784030e-18  3.050767e+03
# QueLH2D2(9)          7.011529e-18  2.696730e+03
# QeuLH2D2(9)          5.069462e-18  2.877449e+03
# QLQLH2D2(9)          6.074280e-18  2.775243e+03
# QLQLH2D5(9)          6.074280e-18  2.775243e+03
# QQLLH2D2(9)          3.502319e-18  3.098339e+03
# eeH4D2(9)            3.117670e-18  3.171276e+03
# LLH4D23(9)           2.463314e-18  3.324268e+03
# LLH4D24(9)           3.595182e-18  3.082165e+03

# %%
#randomly change unknown LECs
for LEC in nudobe.constants.LECs_unknown:
    #draw from a normal distribution
    rand = np.random.normal(1, 0.5)
    
    #randomize the sign except for g_nu^NN
    if LEC != "nuNN":
        sign = np.random.choice([-1, 1])
    else:
        sign = 1
    LEFT_model.LEC[LEC]  *= sign*rand
    SMEFT_model.LEC[LEC] *= sign*rand

# %%
#Get Limits after randomizing LECs
LEFT_lims_rand  = LEFT_model.get_limits(2.3e+26, "136Xe", groups = True)
SMEFT_lims_rand = SMEFT_model.get_limits(2.3e+26, "136Xe")

# %%
#Difference in limits
(LEFT_lims - LEFT_lims_rand)/LEFT_lims
# Out:
#              Limits  Scales [GeV]
# m_bb      -0.331614      0.249032
# VL(6)      0.127766     -0.070738
# VR(6)     -2.774125      0.485255
# T(6)       0.095098     -0.051234
# S(6)       0.000000      0.000000
# V(7)       0.000000      0.000000
# S1(9)      0.354385     -0.091454
# S2(9)     -0.165044      0.030090
# S3(9)      0.565748     -0.181549
# S4(9)      0.065463     -0.013633
# S5(9)     -0.501948      0.078131
# V(9)       0.896482     -0.573971
# Vtilde(9)  0.617850     -0.212142

# %%
(SMEFT_lims - SMEFT_lims_rand)/SMEFT_lims
# Out:
#              Limits [GeV$^{4-d}$]  Scales [GeV]
# LH(5)                   -0.331614      0.249032
# LH(7)                   -0.331614      0.091049
# LHD1(7)                  0.381379     -0.173614
# LHD2(7)                  0.000000      0.000000
# LHDe(7)                  0.127766     -0.046620
# LHW(7)                   0.381099     -0.173437
# LLduD1(7)                0.065099     -0.022692
# LLQdH1(7)               -0.013025      0.004304
# LLQdH2(7)                0.095098     -0.033871
# LLQuH(7)                 0.000000      0.000000
# LeudH(7)                -2.774125      0.357715
# ddueue(9)                0.354385     -0.091454
# dQdueL1(9)               0.896482     -0.573971
# dQdueL2(9)               0.768211     -0.339619
# QudueL1(9)               0.896482     -0.573971
# QudueL2(9)               0.768211     -0.339619
# dQQuLL1(9)              -0.501948      0.078131
# dQQuLL2(9)               0.065463     -0.013633
# QuQuLL1(9)              -0.165044      0.030090
# QuQuLL2(9)               0.565748     -0.181549
# dQdQLL1(9)              -0.165044      0.030090
# dQdQLL2(9)               0.565748     -0.181549
# LLH4W1(9)                0.381099     -0.100717
# deueH2D(9)               0.065463     -0.013633
# dLuLH2D2(9)              0.065463     -0.013633
# duLLH2D(9)               0.065022     -0.013537
# dQLeH2D2(9)              0.896482     -0.573971
# dLQeH2D1(9)              0.847503     -0.456626
# deQLH2D(9)               0.827828     -0.421699
# QueLH2D2(9)              0.896482     -0.573971
# QeuLH2D2(9)              0.768211     -0.339619
# QLQLH2D2(9)              0.354385     -0.091454
# QLQLH2D5(9)              0.354385     -0.091454
# QQLLH2D2(9)              0.387624     -0.103053
# eeH4D2(9)                0.354385     -0.091454
# LLH4D23(9)               0.302505     -0.074711
# LLH4D24(9)               0.387624     -0.103053
